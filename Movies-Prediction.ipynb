# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing the data from 'title.basics.tsv.gz'
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
# importing the data from 'title.akas.tsv.gz'
akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
# importing the data from 'title.ratings.tsv.gz'
ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %% [markdown]
# ## Handling all the \N placeholders into a np.nan

# %%
basics.head()
basics.replace({'\\N':np.nan})
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9820618  tt9916848  tvEpisode              Episode #3.17
# 9820619  tt9916850  tvEpisode              Episode #3.19
# 9820620  tt9916852  tvEpisode              Episode #3.20
# 9820621  tt9916856      short                   The Wind
# 9820622  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9820618              Episode #3.17       0      2010     NaN            NaN
# 9820619              Episode #3.19       0      2010     NaN            NaN
# 9820620              Episode #3.20       0      2010     NaN            NaN
# 9820621                   The Wind       0      2015     NaN             27
# 9820622  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9820618         Action,Drama,Family
# 9820619         Action,Drama,Family
# 9820620         Action,Drama,Family
# 9820621                       Short
# 9820622  Adventure,Animation,Comedy
#
# [9820623 rows x 9 columns]

# %%
akas.head()
akas.replace({'\\N':np.nan})
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 35771901  tt9916852         5             Episódio #3.20     PT       pt
# 35771902  tt9916852         6             Episodio #3.20     IT       it
# 35771903  tt9916852         7               एपिसोड #3.20     IN       hi
# 35771904  tt9916856         1                   The Wind     DE      NaN
# 35771905  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay            NaN               0
# 1                 NaN  literal title               0
# 2         imdbDisplay            NaN               0
# 3         imdbDisplay            NaN               0
# 4         imdbDisplay            NaN               0
# ...               ...            ...             ...
# 35771901          NaN            NaN               0
# 35771902          NaN            NaN               0
# 35771903          NaN            NaN               0
# 35771904  imdbDisplay            NaN               0
# 35771905     original            NaN               1
#
# [35771906 rows x 8 columns]

# %%
ratings.head()
ratings.replace({'\\N':np.nan})
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1966
# 1        tt0000002            5.8       264
# 2        tt0000003            6.5      1811
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2609
# ...            ...            ...       ...
# 1307208  tt9916730            8.3        10
# 1307209  tt9916766            7.0        21
# 1307210  tt9916778            7.2        36
# 1307211  tt9916840            8.8         6
# 1307212  tt9916880            8.2         6
#
# [1307213 rows x 3 columns]

# %% [markdown]
# ## Filtering/Cleaning the datasets

# %%
# Drop rows with null values in the 'runtimeMinutes' column
basics = basics.dropna(subset=['runtimeMinutes'])
basics = basics.dropna(subset=['genres'])
basics.isnull().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres             0
# dtype: int64

# %%
# keeping only full-length movies 
imdb_titles = basics[(basics['titleType'] == 'movie')]
imdb_titles
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 498      tt0000502     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# ...            ...       ...
# 9820514  tt9916622     movie
# 9820541  tt9916680     movie
# 9820553  tt9916706     movie
# 9820563  tt9916730     movie
# 9820573  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# ...                                                    ...
# 9820514        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9820541  De la ilusión al desconcierto: cine colombiano...
# 9820553                                    Dankyavar Danka
# 9820563                                             6 Gunn
# 9820573                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 498                                               Bohemios       0      1905
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# ...                                                    ...     ...       ...
# 9820514        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9820541  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9820553                                    Dankyavar Danka       0      2013
# 9820563                                             6 Gunn       0      2017
# 9820573                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8            \N             45                     Romance
# 144          \N            100      Documentary,News,Sport
# 498          \N            100                          \N
# 570          \N             70  Action,Adventure,Biography
# 587          \N             90                       Drama
# ...         ...            ...                         ...
# 9820514      \N             57                 Documentary
# 9820541      \N            100                 Documentary
# 9820553      \N             \N                      Comedy
# 9820563      \N            116                          \N
# 9820573      \N             49                 Documentary
#
# [643892 rows x 9 columns]

# %%
# keeping the date range between 2000 and 2022
imdb_titles = imdb_titles[(imdb_titles['startYear'] >= '2000') & 
        (imdb_titles['startYear'] <= '2021')]

# %%
# Exclude movies that are included in the documentary category.
is_documentary = imdb_titles['genres'].str.contains('documentary',case=False, na=False)
imdb_titles = imdb_titles[~is_documentary]

# %%
imdb_titles
# Out:
#             tconst titleType  \
# 11636    tt0011801     movie
# 15178    tt0015414     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# ...            ...       ...
# 9820389  tt9916362     movie
# 9820421  tt9916428     movie
# 9820473  tt9916538     movie
# 9820553  tt9916706     movie
# 9820563  tt9916730     movie
#
#                                               primaryTitle  \
# 11636                                     Tötet nicht mehr
# 15178                               La tierra de los toros
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# ...                                                    ...
# 9820389                                              Coven
# 9820421                                The Secret of China
# 9820473                                Kuambil Lagi Hatiku
# 9820553                                    Dankyavar Danka
# 9820563                                             6 Gunn
#
#                                      originalTitle isAdult startYear endYear  \
# 11636                             Tötet nicht mehr       0      2019      \N
# 15178                       La tierra de los toros       0      2000      \N
# 34803                               Kate & Leopold       0      2001      \N
# 61116    El tango del viudo y su espejo deformante       0      2020      \N
# 67669                   The Other Side of the Wind       0      2018      \N
# ...                                            ...     ...       ...     ...
# 9820389                                   Akelarre       0      2020      \N
# 9820421               Hong xing zhao yao Zhong guo       0      2019      \N
# 9820473                        Kuambil Lagi Hatiku       0      2019      \N
# 9820553                            Dankyavar Danka       0      2013      \N
# 9820563                                     6 Gunn       0      2017      \N
#
#         runtimeMinutes                  genres
# 11636               \N            Action,Crime
# 15178               60                      \N
# 34803              118  Comedy,Fantasy,Romance
# 61116               70                   Drama
# 67669              122                   Drama
# ...                ...                     ...
# 9820389             92           Drama,History
# 9820421             \N   Adventure,History,War
# 9820473            123                   Drama
# 9820553             \N                  Comedy
# 9820563            116                      \N
#
# [185980 rows x 9 columns]

# %%
# Filter the DataFrame to include only movies that were released in the United States
USA_movies = akas[(akas['region'] == 'US')]
USA_movies
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35771432  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35771502  tt9916620         1                          The Copeland Case
# 35771591  tt9916702         1              Loving London: The Playground
# 35771634  tt9916756         1                   Pretty Pretty Black Girl
# 35771650  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US       \N  imdbDisplay                     \N               0
# 14           US       \N           \N  literal English title               0
# 33           US       \N  imdbDisplay                     \N               0
# 36           US       \N  alternative                     \N               0
# 41           US       \N  alternative                     \N               0
# ...         ...      ...          ...                    ...             ...
# 35771432     US       \N  imdbDisplay                     \N               0
# 35771502     US       \N  imdbDisplay                     \N               0
# 35771591     US       \N           \N                     \N               0
# 35771634     US       \N  imdbDisplay                     \N               0
# 35771650     US       \N  imdbDisplay                     \N               0
#
# [1434136 rows x 8 columns]

# %%
# Replace "\N" with np.nan
USA_movies = USA_movies.replace('\\N', np.nan)
USA_movies.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
# filtering the basics table to only include US made movies. 
keepers =imdb_titles['tconst'].isin(USA_movies['titleId'])

# %%
# new dataframe with the filtered features
imdb_titles = imdb_titles[keepers]
imdb_titles
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9820156  tt9915872     movie
# 9820296  tt9916170     movie
# 9820305  tt9916190     movie
# 9820389  tt9916362     movie
# 9820421  tt9916428     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9820156                               The Last White Witch
# 9820296                                      The Rehearsal
# 9820305                                          Safeguard
# 9820389                                              Coven
# 9820421                                The Secret of China
#
#                                      originalTitle isAdult startYear endYear  \
# 34803                               Kate & Leopold       0      2001      \N
# 61116    El tango del viudo y su espejo deformante       0      2020      \N
# 67669                   The Other Side of the Wind       0      2018      \N
# 86801                            The Naked Monster       0      2005      \N
# 93938                         Crime and Punishment       0      2002      \N
# ...                                            ...     ...       ...     ...
# 9820156                  My Girlfriend is a Wizard       0      2019      \N
# 9820296                                   O Ensaio       0      2019      \N
# 9820305                                  Safeguard       0      2020      \N
# 9820389                                   Akelarre       0      2020      \N
# 9820421               Hong xing zhao yao Zhong guo       0      2019      \N
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9820156             97       Comedy,Drama,Fantasy
# 9820296             51                      Drama
# 9820305             95  Action,Adventure,Thriller
# 9820389             92              Drama,History
# 9820421             \N      Adventure,History,War
#
# [97202 rows x 9 columns]

# %% [markdown]
# ## Filtering/Cleaning the 'title.ratings.tsv.gz' dataset

# %%
# filtering the ratings table to only include US movies 
ratings_us =ratings['tconst'].isin(USA_movies['titleId'])
ratings_us

ratings = ratings[ratings_us]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1966
# 1        tt0000002            5.8       264
# 4        tt0000005            6.2      2609
# 5        tt0000006            5.2       181
# 6        tt0000007            5.4       816
# ...            ...            ...       ...
# 1307174  tt9916200            8.1       229
# 1307175  tt9916204            8.1       262
# 1307182  tt9916348            8.3        18
# 1307183  tt9916362            6.4      5312
# 1307188  tt9916428            3.8        14
#
# [497209 rows x 3 columns]

# %%
imdb_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97202 entries, 34803 to 9820421
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          97202 non-null  object
#  1   titleType       97202 non-null  object
#  2   primaryTitle    97202 non-null  object
#  3   originalTitle   97202 non-null  object
#  4   isAdult         97202 non-null  object
#  5   startYear       97202 non-null  object
#  6   endYear         97202 non-null  object
#  7   runtimeMinutes  97202 non-null  object
#  8   genres          97202 non-null  object
# dtypes: object(9)
# memory usage: 7.4+ MB

# %%
# changing startYear to a float 
imdb_titles['startYear'] = imdb_titles['startYear'].astype(float)
imdb_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97202 entries, 34803 to 9820421
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          97202 non-null  object
#  1   titleType       97202 non-null  object
#  2   primaryTitle    97202 non-null  object
#  3   originalTitle   97202 non-null  object
#  4   isAdult         97202 non-null  object
#  5   startYear       97202 non-null  float64
#  6   endYear         97202 non-null  object
#  7   runtimeMinutes  97202 non-null  object
#  8   genres          97202 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 7.4+ MB
# /var/folders/mm/04nbg7g95pgdtd1s3081zgfh0000gn/T/ipykernel_66039/1676532349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_titles['startYear'] = imdb_titles['startYear'].astype(float)

# %%
USA_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1434136 entries, 5 to 35771650
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1434136 non-null  object
#  1   ordering         1434136 non-null  int64
#  2   title            1434136 non-null  object
#  3   region           1434136 non-null  object
#  4   language         3907 non-null     object
#  5   types            978363 non-null   object
#  6   attributes       46506 non-null    object
#  7   isOriginalTitle  1432791 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 98.5+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497209 entries, 0 to 1307188
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         497209 non-null  object
#  1   averageRating  497209 non-null  float64
#  2   numVotes       497209 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.2+ MB

# %% [markdown]
# ## Saving our files

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
