# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing the data from 'title.basics.tsv.gz'
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
# importing the data from 'title.akas.tsv.gz'
akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
# importing the data from 'title.ratings.tsv.gz'
ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %% [markdown]
# ## Handling all the \N placeholders into a np.nan

# %%
basics.head()
basics.replace({'\\N':np.nan})
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9842459  tt9916848  tvEpisode              Episode #3.17
# 9842460  tt9916850  tvEpisode              Episode #3.19
# 9842461  tt9916852  tvEpisode              Episode #3.20
# 9842462  tt9916856      short                   The Wind
# 9842463  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9842459              Episode #3.17       0      2010     NaN            NaN
# 9842460              Episode #3.19       0      2010     NaN            NaN
# 9842461              Episode #3.20       0      2010     NaN            NaN
# 9842462                   The Wind       0      2015     NaN             27
# 9842463  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9842459         Action,Drama,Family
# 9842460         Action,Drama,Family
# 9842461         Action,Drama,Family
# 9842462                       Short
# 9842463  Adventure,Animation,Comedy
#
# [9842464 rows x 9 columns]

# %%
akas.head()
akas.replace({'\\N':np.nan})
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 35863468  tt9916852         5             Episódio #3.20     PT       pt
# 35863469  tt9916852         6             Episodio #3.20     IT       it
# 35863470  tt9916852         7               एपिसोड #3.20     IN       hi
# 35863471  tt9916856         1                   The Wind     DE      NaN
# 35863472  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay            NaN               0
# 1                 NaN  literal title               0
# 2         imdbDisplay            NaN               0
# 3         imdbDisplay            NaN               0
# 4         imdbDisplay            NaN               0
# ...               ...            ...             ...
# 35863468          NaN            NaN               0
# 35863469          NaN            NaN               0
# 35863470          NaN            NaN               0
# 35863471  imdbDisplay            NaN               0
# 35863472     original            NaN               1
#
# [35863473 rows x 8 columns]

# %%
ratings.head()
ratings.replace({'\\N':np.nan})
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1971
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1816
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2612
# ...            ...            ...       ...
# 1309290  tt9916730            8.3        10
# 1309291  tt9916766            7.0        21
# 1309292  tt9916778            7.2        36
# 1309293  tt9916840            8.8         6
# 1309294  tt9916880            8.2         6
#
# [1309295 rows x 3 columns]

# %% [markdown]
# ## Filtering/Cleaning the datasets

# %%
# Drop rows with null values in the 'runtimeMinutes' column
basics = basics.dropna(subset=['runtimeMinutes'])
basics = basics.dropna(subset=['genres'])
basics.isnull().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres             0
# dtype: int64

# %%
# keeping only full-length movies 
imdb_titles = basics[(basics['titleType'] == 'movie')]
imdb_titles
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 498      tt0000502     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# ...            ...       ...
# 9842355  tt9916622     movie
# 9842382  tt9916680     movie
# 9842394  tt9916706     movie
# 9842404  tt9916730     movie
# 9842414  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# ...                                                    ...
# 9842355        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9842382  De la ilusión al desconcierto: cine colombiano...
# 9842394                                    Dankyavar Danka
# 9842404                                             6 Gunn
# 9842414                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 498                                               Bohemios       0      1905
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# ...                                                    ...     ...       ...
# 9842355        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9842382  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9842394                                    Dankyavar Danka       0      2013
# 9842404                                             6 Gunn       0      2017
# 9842414                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8            \N             45                     Romance
# 144          \N            100      Documentary,News,Sport
# 498          \N            100                          \N
# 570          \N             70  Action,Adventure,Biography
# 587          \N             90                       Drama
# ...         ...            ...                         ...
# 9842355      \N             57                 Documentary
# 9842382      \N            100                 Documentary
# 9842394      \N             \N                      Comedy
# 9842404      \N            116                          \N
# 9842414      \N             49                 Documentary
#
# [644672 rows x 9 columns]

# %%
# checking the data types of the data
imdb_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644672 entries, 8 to 9842414
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          644672 non-null  object
#  1   titleType       644672 non-null  object
#  2   primaryTitle    644672 non-null  object
#  3   originalTitle   644672 non-null  object
#  4   isAdult         644672 non-null  object
#  5   startYear       644672 non-null  object
#  6   endYear         644672 non-null  object
#  7   runtimeMinutes  644672 non-null  object
#  8   genres          644672 non-null  object
# dtypes: object(9)
# memory usage: 49.2+ MB

# %%
imdb_titles = imdb_titles.replace({'\\N':np.nan})

# %%
imdb_titles.head()
# Out:
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 144  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 498  tt0000502     movie                       Bohemios
# 570  tt0000574     movie    The Story of the Kelly Gang
# 587  tt0000591     movie               The Prodigal Son
#
#                      originalTitle isAdult startYear  endYear runtimeMinutes  \
# 8                       Miss Jerry       0      1894      NaN             45
# 144  The Corbett-Fitzsimmons Fight       0      1897      NaN            100
# 498                       Bohemios       0      1905      NaN            100
# 570    The Story of the Kelly Gang       0      1906      NaN             70
# 587              L'enfant prodigue       0      1907      NaN             90
#
#                          genres
# 8                       Romance
# 144      Documentary,News,Sport
# 498                         NaN
# 570  Action,Adventure,Biography
# 587                       Drama

# %%
imdb_titles['startYear'] = imdb_titles['startYear'].astype(float)
imdb_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644672 entries, 8 to 9842414
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          644672 non-null  object
#  1   titleType       644672 non-null  object
#  2   primaryTitle    644672 non-null  object
#  3   originalTitle   644672 non-null  object
#  4   isAdult         644672 non-null  object
#  5   startYear       554049 non-null  float64
#  6   endYear         0 non-null       float64
#  7   runtimeMinutes  406477 non-null  object
#  8   genres          572685 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 49.2+ MB

# %%
imdb_titles[(imdb_titles['startYear'] >= 2000) & (imdb_titles['startYear'] <= 2021)]
# Out:
#             tconst titleType  \
# 11636    tt0011801     movie
# 13082    tt0013274     movie
# 15178    tt0015414     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# ...            ...       ...
# 9842355  tt9916622     movie
# 9842382  tt9916680     movie
# 9842394  tt9916706     movie
# 9842404  tt9916730     movie
# 9842414  tt9916754     movie
#
#                                               primaryTitle  \
# 11636                                     Tötet nicht mehr
# 13082                          Istoriya grazhdanskoy voyny
# 15178                               La tierra de los toros
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# ...                                                    ...
# 9842355        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9842382  De la ilusión al desconcierto: cine colombiano...
# 9842394                                    Dankyavar Danka
# 9842404                                             6 Gunn
# 9842414                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 11636                                     Tötet nicht mehr       0     2019.0
# 13082                          Istoriya grazhdanskoy voyny       0     2021.0
# 15178                               La tierra de los toros       0     2000.0
# 34803                                       Kate & Leopold       0     2001.0
# 61116            El tango del viudo y su espejo deformante       0     2020.0
# ...                                                    ...     ...        ...
# 9842355        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9842382  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9842394                                    Dankyavar Danka       0     2013.0
# 9842404                                             6 Gunn       0     2017.0
# 9842414                     Chico Albuquerque - Revelações       0     2013.0
#
#          endYear runtimeMinutes                  genres
# 11636        NaN            NaN            Action,Crime
# 13082        NaN             94             Documentary
# 15178        NaN             60                     NaN
# 34803        NaN            118  Comedy,Fantasy,Romance
# 61116        NaN             70                   Drama
# ...          ...            ...                     ...
# 9842355      NaN             57             Documentary
# 9842382      NaN            100             Documentary
# 9842394      NaN            NaN                  Comedy
# 9842404      NaN            116                     NaN
# 9842414      NaN             49             Documentary
#
# [272654 rows x 9 columns]

# %%
# Exclude movies that are included in the documentary category.
is_documentary = imdb_titles['genres'].str.contains('documentary',case=False, na=False)
imdb_titles = imdb_titles[~is_documentary]

# %%
imdb_titles
# Out:
#             tconst titleType                 primaryTitle  \
# 8        tt0000009     movie                   Miss Jerry
# 498      tt0000502     movie                     Bohemios
# 570      tt0000574     movie  The Story of the Kelly Gang
# 587      tt0000591     movie             The Prodigal Son
# 610      tt0000615     movie           Robbery Under Arms
# ...            ...       ...                          ...
# 9842262  tt9916428     movie          The Secret of China
# 9842314  tt9916538     movie          Kuambil Lagi Hatiku
# 9842354  tt9916620     movie            The Copeland Case
# 9842394  tt9916706     movie              Dankyavar Danka
# 9842404  tt9916730     movie                       6 Gunn
#
#                         originalTitle isAdult  startYear  endYear  \
# 8                          Miss Jerry       0     1894.0      NaN
# 498                          Bohemios       0     1905.0      NaN
# 570       The Story of the Kelly Gang       0     1906.0      NaN
# 587                 L'enfant prodigue       0     1907.0      NaN
# 610                Robbery Under Arms       0     1907.0      NaN
# ...                               ...     ...        ...      ...
# 9842262  Hong xing zhao yao Zhong guo       0     2019.0      NaN
# 9842314           Kuambil Lagi Hatiku       0     2019.0      NaN
# 9842354             The Copeland Case       0        NaN      NaN
# 9842394               Dankyavar Danka       0     2013.0      NaN
# 9842404                        6 Gunn       0     2017.0      NaN
#
#         runtimeMinutes                      genres
# 8                   45                     Romance
# 498                100                         NaN
# 570                 70  Action,Adventure,Biography
# 587                 90                       Drama
# 610                NaN                       Drama
# ...                ...                         ...
# 9842262            NaN       Adventure,History,War
# 9842314            123                       Drama
# 9842354            NaN                       Drama
# 9842394            NaN                      Comedy
# 9842404            116                         NaN
#
# [522486 rows x 9 columns]

# %%
# Filter the DataFrame to include only movies that were released in the United States
USA_movies = akas[(akas['region'] == 'US')]
USA_movies
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35862999  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35863069  tt9916620         1                          The Copeland Case
# 35863158  tt9916702         1              Loving London: The Playground
# 35863201  tt9916756         1                   Pretty Pretty Black Girl
# 35863217  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US       \N  imdbDisplay                     \N               0
# 14           US       \N           \N  literal English title               0
# 33           US       \N  imdbDisplay                     \N               0
# 36           US       \N  alternative                     \N               0
# 41           US       \N  alternative                     \N               0
# ...         ...      ...          ...                    ...             ...
# 35862999     US       \N  imdbDisplay                     \N               0
# 35863069     US       \N  imdbDisplay                     \N               0
# 35863158     US       \N           \N                     \N               0
# 35863201     US       \N  imdbDisplay                     \N               0
# 35863217     US       \N  imdbDisplay                     \N               0
#
# [1435910 rows x 8 columns]

# %% [raw]
# # Replace "\N" with np.nan
# USA_movies = USA_movies.replace('\\N', np.nan)
# USA_movies.head()

# %%
# filtering the basics table to only include US made movies. 
keepers =imdb_titles['tconst'].isin(USA_movies['titleId'])

# %%
# new dataframe with the filtered features
imdb_titles = imdb_titles[keepers]
imdb_titles
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 625      tt0000630     movie                          Hamlet
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# ...            ...       ...                             ...
# 9842145  tt9916188     movie                        Minotaur
# 9842146  tt9916190     movie                       Safeguard
# 9842230  tt9916362     movie                           Coven
# 9842262  tt9916428     movie             The Secret of China
# 9842354  tt9916620     movie               The Copeland Case
#
#                           originalTitle isAdult  startYear  endYear  \
# 8                            Miss Jerry       0     1894.0      NaN
# 570         The Story of the Kelly Gang       0     1906.0      NaN
# 587                   L'enfant prodigue       0     1907.0      NaN
# 625                              Amleto       0     1908.0      NaN
# 672      The Fairylogue and Radio-Plays       0     1908.0      NaN
# ...                                 ...     ...        ...      ...
# 9842145                        Minotaur       0        NaN      NaN
# 9842146                       Safeguard       0     2020.0      NaN
# 9842230                        Akelarre       0     2020.0      NaN
# 9842262    Hong xing zhao yao Zhong guo       0     2019.0      NaN
# 9842354               The Copeland Case       0        NaN      NaN
#
#         runtimeMinutes                      genres
# 8                   45                     Romance
# 570                 70  Action,Adventure,Biography
# 587                 90                       Drama
# 625                NaN                       Drama
# 672                120           Adventure,Fantasy
# ...                ...                         ...
# 9842145            NaN                    Thriller
# 9842146             95   Action,Adventure,Thriller
# 9842230             92               Drama,History
# 9842262            NaN       Adventure,History,War
# 9842354            NaN                       Drama
#
# [245272 rows x 9 columns]

# %% [markdown]
# ## Filtering/Cleaning the 'title.ratings.tsv.gz' dataset

# %%
# filtering the ratings table to only include US movies 
ratings_us =ratings['tconst'].isin(USA_movies['titleId'])
ratings_us

ratings = ratings[ratings_us]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1971
# 1        tt0000002            5.8       263
# 4        tt0000005            6.2      2612
# 5        tt0000006            5.1       181
# 6        tt0000007            5.4       818
# ...            ...            ...       ...
# 1309256  tt9916200            8.1       229
# 1309257  tt9916204            8.1       262
# 1309264  tt9916348            8.3        18
# 1309265  tt9916362            6.4      5322
# 1309270  tt9916428            3.8        14
#
# [498013 rows x 3 columns]

# %%
imdb_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245272 entries, 8 to 9842354
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          245272 non-null  object
#  1   titleType       245272 non-null  object
#  2   primaryTitle    245272 non-null  object
#  3   originalTitle   245272 non-null  object
#  4   isAdult         245272 non-null  object
#  5   startYear       191466 non-null  float64
#  6   endYear         0 non-null       float64
#  7   runtimeMinutes  164950 non-null  object
#  8   genres          234626 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 18.7+ MB

# %%
USA_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1435910 entries, 5 to 35863217
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1435910 non-null  object
#  1   ordering         1435910 non-null  int64
#  2   title            1435910 non-null  object
#  3   region           1435910 non-null  object
#  4   language         1435910 non-null  object
#  5   types            1435910 non-null  object
#  6   attributes       1435910 non-null  object
#  7   isOriginalTitle  1435910 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 98.6+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498013 entries, 0 to 1309270
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         498013 non-null  object
#  1   averageRating  498013 non-null  float64
#  2   numVotes       498013 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.2+ MB

# %% [markdown]
# ## Saving our files

# %%
imdb_titles.head()

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
