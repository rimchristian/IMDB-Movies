# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing the data from 'title.basics.tsv.gz'
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
# importing the data from 'title.akas.tsv.gz'
akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
# importing the data from 'title.ratings.tsv.gz'
ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %% [markdown]
# ## Identifying and replacing missing values.

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %% [markdown]
#  ## Handling all the \N placeholders into a np.nan

# %%
akas.head()
akas.replace({'\\N':np.nan})
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 35320158  tt9916852         5             Episódio #3.20     PT       pt
# 35320159  tt9916852         6             Episodio #3.20     IT       it
# 35320160  tt9916852         7               एपिसोड #3.20     IN       hi
# 35320161  tt9916856         1                   The Wind     DE      NaN
# 35320162  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay            NaN               0
# 1                 NaN  literal title               0
# 2         imdbDisplay            NaN               0
# 3         imdbDisplay            NaN               0
# 4         imdbDisplay            NaN               0
# ...               ...            ...             ...
# 35320158          NaN            NaN               0
# 35320159          NaN            NaN               0
# 35320160          NaN            NaN               0
# 35320161  imdbDisplay            NaN               0
# 35320162     original            NaN               1
#
# [35320163 rows x 8 columns]

# %%
ratings.head()
ratings.replace({'\\N':np.nan})
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1962
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1800
# 3        tt0000004            5.6       179
# 4        tt0000005            6.2      2601
# ...            ...            ...       ...
# 1292931  tt9916730            8.3        10
# 1292932  tt9916766            7.0        21
# 1292933  tt9916778            7.2        36
# 1292934  tt9916840            8.8         6
# 1292935  tt9916880            8.2         6
#
# [1292936 rows x 3 columns]

# %% [markdown]
# ## Filtering/Cleaning the 'title.basics.tsv.gz ' dataset

# %%
# Drop rows with null values in the 'runtimeMinutes' column
basics = basics.dropna(subset=['runtimeMinutes'])
basics = basics.dropna(subset=['genres'])
basics.isnull().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 0
# startYear          150038
# endYear           2235835
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %%
# Replace "\N" with np.nan
basics = basics.replace('\\N', np.nan)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
# keeping only the movie 'titleType'
imdb_titles = basics[(basics['titleType'] == 'movie')]
imdb_titles
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9707853  tt9916362     movie
# 9707937  tt9916538     movie
# 9707978  tt9916622     movie
# 9708005  tt9916680     movie
# 9708037  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9707853                                              Coven
# 9707937                                Kuambil Lagi Hatiku
# 9707978        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9708005  De la ilusión al desconcierto: cine colombiano...
# 9708037                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# ...                                                    ...     ...       ...
# 9707853                                           Akelarre       0      2020
# 9707937                                Kuambil Lagi Hatiku       0      2019
# 9707978        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9708005  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9708037                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 144         NaN            100      Documentary,News,Sport
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# ...         ...            ...                         ...
# 9707853     NaN             92               Drama,History
# 9707937     NaN            123                       Drama
# 9707978     NaN             57                 Documentary
# 9708005     NaN            100                 Documentary
# 9708037     NaN             49                 Documentary
#
# [378060 rows x 9 columns]

# %%
# keeping the date range between 2000 and 2022
imdb_titles = imdb_titles[(imdb_titles['startYear'] >= '2000') & \
        (imdb_titles['startYear'] <= '2021')]

# %%
# Exclude movies that are included in the documentary category.
is_documentary = imdb_titles['genres'].str.contains('documentary',case=False)
imdb_titles = imdb_titles[~is_documentary]

# %%
imdb_titles
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 77964    tt0079644     movie
# 86801    tt0088751     movie
# ...            ...       ...
# 9707760  tt9916170     movie
# 9707769  tt9916190     movie
# 9707808  tt9916270     movie
# 9707853  tt9916362     movie
# 9707937  tt9916538     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 77964                                        November 1828
# 86801                                    The Naked Monster
# ...                                                    ...
# 9707760                                      The Rehearsal
# 9707769                                          Safeguard
# 9707808                           Il talento del calabrone
# 9707853                                              Coven
# 9707937                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult startYear endYear  \
# 34803                               Kate & Leopold       0      2001     NaN
# 61116    El tango del viudo y su espejo deformante       0      2020     NaN
# 67669                   The Other Side of the Wind       0      2018     NaN
# 77964                                November 1828       0      2001     NaN
# 86801                            The Naked Monster       0      2005     NaN
# ...                                            ...     ...       ...     ...
# 9707760                                   O Ensaio       0      2019     NaN
# 9707769                                  Safeguard       0      2020     NaN
# 9707808                   Il talento del calabrone       0      2020     NaN
# 9707853                                   Akelarre       0      2020     NaN
# 9707937                        Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 77964              140                  Drama,War
# 86801              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9707760             51                      Drama
# 9707769             95  Action,Adventure,Thriller
# 9707808             84                   Thriller
# 9707853             92              Drama,History
# 9707937            123                      Drama
#
# [137569 rows x 9 columns]

# %%
# Filter the DataFrame to include only movies that were released in the United States
USA_movies = akas[(akas['region'] == 'US')]
USA_movies
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35319689  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35319759  tt9916620         1                          The Copeland Case
# 35319848  tt9916702         1              Loving London: The Playground
# 35319891  tt9916756         1                   Pretty Pretty Black Girl
# 35319907  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US       \N  imdbDisplay                     \N               0
# 14           US       \N           \N  literal English title               0
# 33           US       \N  imdbDisplay                     \N               0
# 36           US       \N  alternative                     \N               0
# 41           US       \N  alternative                     \N               0
# ...         ...      ...          ...                    ...             ...
# 35319689     US       \N  imdbDisplay                     \N               0
# 35319759     US       \N  imdbDisplay                     \N               0
# 35319848     US       \N           \N                     \N               0
# 35319891     US       \N  imdbDisplay                     \N               0
# 35319907     US       \N  imdbDisplay                     \N               0
#
# [1423787 rows x 8 columns]

# %%
# Replace "\N" with np.nan
USA_movies = USA_movies.replace('\\N', np.nan)
USA_movies.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
# filtering the basics table to only include US made movies. 
keepers =imdb_titles['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34803      True
# 61116      True
# 67669      True
# 77964      True
# 86801      True
#            ...
# 9707760    True
# 9707769    True
# 9707808    True
# 9707853    True
# 9707937    True
# Name: tconst, Length: 146382, dtype: bool

# %%
# new dataframe with the filtered features
imdb_titles = imdb_titles[keepers]
imdb_titles
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 77964    tt0079644     movie
# 86801    tt0088751     movie
# ...            ...       ...
# 9707760  tt9916170     movie
# 9707769  tt9916190     movie
# 9707808  tt9916270     movie
# 9707853  tt9916362     movie
# 9707937  tt9916538     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 77964                                        November 1828
# 86801                                    The Naked Monster
# ...                                                    ...
# 9707760                                      The Rehearsal
# 9707769                                          Safeguard
# 9707808                           Il talento del calabrone
# 9707853                                              Coven
# 9707937                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult startYear endYear  \
# 34803                               Kate & Leopold       0      2001     NaN
# 61116    El tango del viudo y su espejo deformante       0      2020     NaN
# 67669                   The Other Side of the Wind       0      2018     NaN
# 77964                                November 1828       0      2001     NaN
# 86801                            The Naked Monster       0      2005     NaN
# ...                                            ...     ...       ...     ...
# 9707760                                   O Ensaio       0      2019     NaN
# 9707769                                  Safeguard       0      2020     NaN
# 9707808                   Il talento del calabrone       0      2020     NaN
# 9707853                                   Akelarre       0      2020     NaN
# 9707937                        Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 77964              140                  Drama,War
# 86801              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9707760             51                      Drama
# 9707769             95  Action,Adventure,Thriller
# 9707808             84                   Thriller
# 9707853             92              Drama,History
# 9707937            123                      Drama
#
# [146382 rows x 9 columns]

# %% [markdown]
# ## Filtering/Cleaning the 'title.akas.tsv.gz' dataset

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
# Replace "\N" with np.nan
akas = akas.replace('\\N', np.nan)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
USA_movies = akas[(akas['region'] == 'US')]
USA_movies
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35319689  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35319759  tt9916620         1                          The Copeland Case
# 35319848  tt9916702         1              Loving London: The Playground
# 35319891  tt9916756         1                   Pretty Pretty Black Girl
# 35319907  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 35319689     US      NaN  imdbDisplay                    NaN               0
# 35319759     US      NaN  imdbDisplay                    NaN               0
# 35319848     US      NaN          NaN                    NaN               0
# 35319891     US      NaN  imdbDisplay                    NaN               0
# 35319907     US      NaN  imdbDisplay                    NaN               0
#
# [1423787 rows x 8 columns]

# %% [markdown]
# ## Filtering/Cleaning the 'title.ratings.tsv.gz' dataset

# %%
# Replace "\N" with np.nan
ratings = ratings.replace('\\N', np.nan)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1962
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1800
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2601

# %%
# filtering the ratings table to only include US movies 
ratings_us =ratings['tconst'].isin(USA_movies['titleId'])
ratings_us

ratings = ratings[ratings_us]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1962
# 1        tt0000002            5.8       263
# 4        tt0000005            6.2      2601
# 5        tt0000006            5.1       178
# 6        tt0000007            5.4       817
# ...            ...            ...       ...
# 1292901  tt9916200            8.2       225
# 1292902  tt9916204            8.2       257
# 1292909  tt9916348            8.3        18
# 1292910  tt9916362            6.4      5244
# 1292914  tt9916428            3.8        14
#
# [493030 rows x 3 columns]

# %%
imdb_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137569 entries, 34803 to 9707937
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          137569 non-null  object
#  1   titleType       137569 non-null  object
#  2   primaryTitle    137569 non-null  object
#  3   originalTitle   137569 non-null  object
#  4   isAdult         137569 non-null  object
#  5   startYear       137569 non-null  object
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  137569 non-null  object
#  8   genres          137569 non-null  object
# dtypes: object(9)
# memory usage: 10.5+ MB

# %%
USA_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 548756 entries, 5 to 35319510
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   titleId          548756 non-null  object
#  1   ordering         548756 non-null  int64
#  2   title            548756 non-null  object
#  3   region           548756 non-null  object
#  4   language         2642 non-null    object
#  5   types            361727 non-null  object
#  6   attributes       29304 non-null   object
#  7   isOriginalTitle  548756 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 37.7+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 493030 entries, 0 to 1292914
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         493030 non-null  object
#  1   averageRating  493030 non-null  float64
#  2   numVotes       493030 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.0+ MB

# %% [markdown]
# ## Saving our files

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay            NaN              0.0
# 1          NaN  literal title              0.0
# 2  imdbDisplay            NaN              0.0
# 3  imdbDisplay            NaN              0.0
# 4  imdbDisplay            NaN              0.0

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1962
# 1  tt0000002            5.8       263
# 2  tt0000005            6.2      2601
# 3  tt0000006            5.1       178
# 4  tt0000007            5.4       817
